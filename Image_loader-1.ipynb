# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
from PIL import Image

# %%
df = pd.read_csv('HAM10000_metadata')

# %%
df.head(5)
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset
# 0  vidir_modern
# 1  vidir_modern
# 2  vidir_modern
# 3  vidir_modern
# 4  vidir_modern

# %%
path = {os.path.splitext(os.path.basename(x))[0]: x
                     for x in glob(os.path.join('Dataset/', '*', '*.jpg'))}

# %%
path
# Out:
# {'ISIC_0024306': 'Dataset\\Images\\ISIC_0024306.jpg',
#  'ISIC_0024307': 'Dataset\\Images\\ISIC_0024307.jpg',
#  'ISIC_0024308': 'Dataset\\Images\\ISIC_0024308.jpg',
#  'ISIC_0024309': 'Dataset\\Images\\ISIC_0024309.jpg',
#  'ISIC_0024310': 'Dataset\\Images\\ISIC_0024310.jpg',
#  'ISIC_0024311': 'Dataset\\Images\\ISIC_0024311.jpg',
#  'ISIC_0024312': 'Dataset\\Images\\ISIC_0024312.jpg',
#  'ISIC_0024313': 'Dataset\\Images\\ISIC_0024313.jpg',
#  'ISIC_0024314': 'Dataset\\Images\\ISIC_0024314.jpg',
#  'ISIC_0024315': 'Dataset\\Images\\ISIC_0024315.jpg',
#  'ISIC_0024316': 'Dataset\\Images\\ISIC_0024316.jpg',
#  'ISIC_0024317': 'Dataset\\Images\\ISIC_0024317.jpg',
#  'ISIC_0024318': 'Dataset\\Images\\ISIC_0024318.jpg',
#  'ISIC_0024319': 'Dataset\\Images\\ISIC_0024319.jpg',
#  'ISIC_0024320': 'Dataset\\Images\\ISIC_0024320.jpg',
#  'ISIC_0024321': 'Dataset\\Images\\ISIC_0024321.jpg',
#  'ISIC_0024322': 'Dataset\\Images\\ISIC_0024322.jpg',
# ...

# %%
df['path'] = df['image_id'].map(path.get)

# %%
df['image'] = df['path'].map(lambda x: np.asarray(Image.open(x).resize((32,32))))

# %%
df.head(5)
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset                             path  \
# 0  vidir_modern  Dataset\Images\ISIC_0027419.jpg
# 1  vidir_modern  Dataset\Images\ISIC_0025030.jpg
# 2  vidir_modern  Dataset\Images\ISIC_0026769.jpg
# 3  vidir_modern  Dataset\Images\ISIC_0025661.jpg
# 4  vidir_modern  Dataset\Images\ISIC_0031633.jpg
#
#                                                image
# 0  [[[191, 152, 192], [194, 154, 193], [196, 152,...
# 1  [[[24, 14, 29], [56, 39, 64], [106, 80, 112], ...
# 2  [[[190, 136, 150], [199, 145, 161], [200, 141,...
# ...

# %%
img_array = df['image'].values

# %%
np.save('array_col.npy', img_array)
